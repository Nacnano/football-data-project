# %%
# !pip install fuzzywuzzy
# !pip install python-Levenshtein
# Out:
# Requirement already satisfied: fuzzywuzzy in /home/kheaw/champ/football-data-project/.venv/lib/python3.13/site-packages (0.18.0)
# Requirement already satisfied: python-Levenshtein in /home/kheaw/champ/football-data-project/.venv/lib/python3.13/site-packages (0.27.3)
# Requirement already satisfied: Levenshtein==0.27.3 in /home/kheaw/champ/football-data-project/.venv/lib/python3.13/site-packages (from python-Levenshtein) (0.27.3)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /home/kheaw/champ/football-data-project/.venv/lib/python3.13/site-packages (from Levenshtein==0.27.3->python-Levenshtein) (3.14.3)

# %% [markdown]
# # Map UEFA score
#
# map score to each fbref data by chooing best either team score or country part

# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import process
from glob import glob
import os

# --- Display setup ---
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# --- Paths ---
data_path = "../data/fbref/"
modified_path = "../data/fbref/modified"
uefa_data_path = "../data/uefa/"
os.makedirs(modified_path, exist_ok=True)

# --- Preload ranking data once ---
def load_uefa_ranking(year):
    rankingdf = pd.read_csv(os.path.join(uefa_data_path, f'UEFA_Ranking_{year}.csv'))
    rankingdf['used_point'] = np.where(
        rankingdf['Total Points'] >= rankingdf['Country Part'],
        rankingdf['Total Points'],
        rankingdf['Country Part']
    )

    choices = rankingdf['team'].unique()
    return rankingdf,choices

# --- Matching function ---
def match_team(name,rankingdf,choices):
    if pd.isna(name): 
        return np.nan
    match, score = process.extractOne(name, choices)
    if score > 70:
        return rankingdf.loc[rankingdf['team'] == match, 'used_point'].iloc[0]
    return 0

# --- Outfield Players ---
fbref_files = glob(f"{data_path}/**/*.csv", recursive=True)

for file in fbref_files:
    subfolder,filename = file.split('/')[-2:]
    year = '20'+file.split('/')[-1][-6:-4]
    print(f"⚙️ Processing: {file}", f'\nyear is {year}')
    rankingdf,choices = load_uefa_ranking(year)

    df = pd.read_csv(os.path.join(file))
    
    # Map UEFA coefficient
    df['team_score'] = df['team'].apply(lambda x: match_team(x, rankingdf, choices))
    #df_encoded.drop(columns=['team'], inplace=True)

    # Save cleaned file
    os.makedirs(os.path.join(modified_path,subfolder), exist_ok=True)
    output_file = os.path.join(modified_path, subfolder, filename)
    df.to_csv(output_file, index=False)
    print(f"Saved to: {output_file}")
# Out:
# ⚙️ Processing: ../data/fbref/PL_team/PL_team_22_23.csv
# year is 2023
# Saved to: ../data/fbref/modified/PL_team/PL_team_22_23.csv
# ⚙️ Processing: ../data/fbref/PL_team/PL_team_24_25.csv
# year is 2025
# Saved to: ../data/fbref/modified/PL_team/PL_team_24_25.csv
# ⚙️ Processing: ../data/fbref/PL_team/PL_team_20_21.csv
# year is 2021
# Saved to: ../data/fbref/modified/PL_team/PL_team_20_21.csv
# ⚙️ Processing: ../data/fbref/PL_team/PL_team_21_22.csv
# year is 2022
# Saved to: ../data/fbref/modified/PL_team/PL_team_21_22.csv
# ⚙️ Processing: ../data/fbref/PL_team/PL_team_23_24.csv
# year is 2024
# Saved to: ../data/fbref/modified/PL_team/PL_team_23_24.csv
# ⚙️ Processing: ../data/fbref/PL_team/PL_team_25_26.csv
# year is 2026
# Saved to: ../data/fbref/modified/PL_team/PL_team_25_26.csv
# ⚙️ Processing: ../data/fbref/modified/PL_team/PL_team_22_23.csv
# year is 2023
# Saved to: ../data/fbref/modified/PL_team/PL_team_22_23.csv
# ⚙️ Processing: ../data/fbref/modified/PL_team/PL_team_24_25.csv
# year is 2025
# Saved to: ../data/fbref/modified/PL_team/PL_team_24_25.csv
# ⚙️ Processing: ../data/fbref/modified/PL_team/PL_team_20_21.csv
# year is 2021
# Saved to: ../data/fbref/modified/PL_team/PL_team_20_21.csv
# ⚙️ Processing: ../data/fbref/modified/PL_team/PL_team_21_22.csv
# year is 2022
# Saved to: ../data/fbref/modified/PL_team/PL_team_21_22.csv
# ⚙️ Processing: ../data/fbref/modified/PL_team/PL_team_23_24.csv
# year is 2024
# Saved to: ../data/fbref/modified/PL_team/PL_team_23_24.csv
# ⚙️ Processing: ../data/fbref/modified/PL_team/PL_team_25_26.csv
# year is 2026
# Saved to: ../data/fbref/modified/PL_team/PL_team_25_26.csv
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_21_22.csv
# year is 2022
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_21_22.csv
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_20_21.csv
# year is 2021
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_20_21.csv
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_22_23.csv
# year is 2023
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_22_23.csv
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_25_26.csv
# year is 2026
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_25_26.csv
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_24_25.csv
# year is 2025
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_24_25.csv
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_23_24.csv
# year is 2024
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_23_24.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_21_22.csv
# year is 2022
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_21_22.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_23_24.csv
# year is 2024
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_23_24.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_22_23.csv
# year is 2023
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_22_23.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_24_25.csv
# year is 2025
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_24_25.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_20_21.csv
# year is 2021
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_20_21.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_25_26.csv
# year is 2026
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_25_26.csv
# ⚙️ Processing: ../data/fbref/PL_keeper/PL_keeper_21_22.csv
# year is 2022
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_21_22.csv
# ⚙️ Processing: ../data/fbref/PL_keeper/PL_keeper_20_21.csv
# year is 2021
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_20_21.csv
# ⚙️ Processing: ../data/fbref/PL_keeper/PL_keeper_22_23.csv
# year is 2023
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_22_23.csv
# ⚙️ Processing: ../data/fbref/PL_keeper/PL_keeper_25_26.csv
# year is 2026
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_25_26.csv
# ⚙️ Processing: ../data/fbref/PL_keeper/PL_keeper_24_25.csv
# year is 2025
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_24_25.csv
# ⚙️ Processing: ../data/fbref/PL_keeper/PL_keeper_23_24.csv
# year is 2024
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_23_24.csv
# ⚙️ Processing: ../data/fbref/PL_outfield/PL_outfield_21_22.csv
# year is 2022
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_21_22.csv
# ⚙️ Processing: ../data/fbref/PL_outfield/PL_outfield_23_24.csv
# year is 2024
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_23_24.csv
# ⚙️ Processing: ../data/fbref/PL_outfield/PL_outfield_22_23.csv
# year is 2023
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_22_23.csv
# ⚙️ Processing: ../data/fbref/PL_outfield/PL_outfield_24_25.csv
# year is 2025
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_24_25.csv
# ⚙️ Processing: ../data/fbref/PL_outfield/PL_outfield_20_21.csv
# year is 2021
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_20_21.csv
# ⚙️ Processing: ../data/fbref/PL_outfield/PL_outfield_25_26.csv
# year is 2026
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_25_26.csv

# %% [markdown]
# # Feature engineering : outfield

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
original_df = pd.read_csv('../data/fbref/modified/PL_outfield/PL_outfield_25_26.csv')
original_df.describe().T
# Out:
#                               count         mean          std     min  \
# ranker                        450.0     0.000000     0.000000     0.0
# birth_year                    450.0  1999.302222     4.114967  1986.0
# games                         450.0     6.815556     2.987610     1.0
# games_starts                  450.0     4.888889     3.576228     0.0
# minutes                       450.0   439.013333   298.906649     1.0
# minutes_90s                   450.0     4.875556     3.320568     0.0
# goals                         450.0     0.568889     1.173543     0.0
# assists                       450.0     0.393333     0.720956     0.0
# goals_assists                 450.0     0.962222     1.525111     0.0
# goals_pens                    450.0     0.528889     1.094758     0.0
# pens_made                     450.0     0.040000     0.217702     0.0
# pens_att                      450.0     0.048889     0.262439     0.0
# cards_yellow                  450.0     0.797778     1.060106     0.0
# cards_red                     450.0     0.024444     0.154596     0.0
# xg                            450.0     0.584444     0.974109     0.0
# npxg                          450.0     0.546000     0.876135     0.0
# xg_assist                     450.0     0.416889     0.570803     0.0
# npxg_xg_assist                450.0     0.965556     1.221774     0.0
# progressive_carries           450.0     7.502222     9.060610     0.0
# progressive_passes            450.0    16.024444    16.432811     0.0
# progressive_passes_received   450.0    15.837778    19.260907     0.0
# goals_per90                   450.0     0.116178     0.351002     0.0
# assists_per90                 450.0     0.100800     0.354337     0.0
# goals_assists_per90           450.0     0.217044     0.499782     0.0
# goals_pens_per90              450.0     0.109089     0.347106     0.0
# goals_assists_pens_per90      450.0     0.209956     0.497024     0.0
# xg_per90                      450.0     0.128511     0.181213     0.0
# xg_assist_per90               450.0     0.088911     0.138949     0.0
# xg_xg_assist_per90            450.0     0.217289     0.253622     0.0
# npxg_per90                    450.0     0.122156     0.172220     0.0
# npxg_xg_assist_per90          450.0     0.210978     0.246932     0.0
# shots                         450.0     5.217778     5.778128     0.0
# shots_on_target               450.0     1.704444     2.507757     0.0
# shots_on_target_pct           450.0    22.489778    25.221485     0.0
# shots_per90                   450.0     1.242644     1.463860     0.0
# shots_on_target_per90         450.0     0.400800     0.750248     0.0
# goals_per_shot                450.0     0.060378     0.122337     0.0
# goals_per_shot_on_target      450.0     0.158711     0.283936     0.0
# average_shot_distance         450.0    13.014000     8.772434     0.0
# shots_free_kicks              450.0     0.140000     0.486293     0.0
# xg_assist                        0.000     0.200     0.6000      3.50
# npxg_xg_assist                   0.100     0.600     1.3000     11.40
# progressive_carries              1.000     4.500    11.0000     63.00
# progressive_passes               3.000    11.000    25.0000     89.00
# progressive_passes_received      2.000     8.000    25.0000    108.00
# goals_per90                      0.000     0.000     0.1400      5.63
# assists_per90                    0.000     0.000     0.1100      5.29
# goals_assists_per90              0.000     0.000     0.3000      5.63
# goals_pens_per90                 0.000     0.000     0.1200      5.63
# goals_assists_pens_per90         0.000     0.000     0.2975      5.63
# xg_per90                         0.010     0.060     0.1800      1.40
# xg_assist_per90                  0.000     0.040     0.1200      1.10
# xg_xg_assist_per90               0.040     0.140     0.3075      1.91
# npxg_per90                       0.010     0.060     0.1700      1.40
# npxg_xg_assist_per90             0.040     0.140     0.3000      1.91
# shots                            1.000     4.000     8.0000     43.00
# shots_on_target                  0.000     1.000     2.0000     25.00
# shots_on_target_pct              0.000    20.000    37.5000    100.00
# shots_per90                      0.210     0.855     1.7675     11.25
# shots_on_target_per90            0.000     0.160     0.5700      8.18
# goals_per_shot                   0.000     0.000     0.0900      1.00
# goals_per_shot_on_target         0.000     0.000     0.2500      1.00
# average_shot_distance            7.350    14.450    19.6000     39.10
# shots_free_kicks                 0.000     0.000     0.0000      4.00
# npxg_per_shot                    0.020     0.060     0.1000      0.78
# xg_net                          -0.275     0.000     0.0000      2.80
# npxg_net                        -0.275     0.000     0.0000      2.80
# passes_completed                49.250   122.000   264.5000    704.00
# passes                          64.000   157.000   334.0000    795.00
# passes_pct                      70.425    78.650    85.1750    100.00
# passes_total_distance          733.000  2062.500  4684.5000  12732.00
# passes_progressive_distance    166.250   594.500  1534.7500   6080.00
# passes_completed_short          22.250    57.000   117.7500    299.00
# passes_short                    27.000    66.000   131.7500    328.00
# passes_pct_short                84.000    89.900    93.8000    100.00
# passes_completed_medium         15.250    47.000   111.2500    359.00
# passes_medium                   21.250    57.000   130.0000    381.00
# passes_pct_medium               75.000    84.850    91.6750    100.00
# passes_completed_long            2.000     9.000    22.0000    103.00
# passes_long                      5.000    17.000    42.0000    252.00
# passes_pct_long                 36.025    50.000    60.9000    100.00
# pass_xa                          0.000     0.200     0.5000      2.50
# xg_assist_net                   -0.200     0.000     0.0000      2.80
# assisted_shots                   1.000     2.000     5.0000     28.00
# passes_into_final_third          3.000     9.000    19.0000     88.00
# passes_into_penalty_area         0.000     2.000     5.0000     24.00
# crosses_into_penalty_area        0.000     0.000     1.0000     17.00
# passes_live                     59.000   141.000   294.7500    733.00
# passes_dead                      2.000     9.000    27.0000    149.00
# passes_free_kicks                0.000     2.000     7.0000     57.00
# through_balls                    0.000     0.000     1.0000      9.00
# passes_switches                  0.000     0.000     1.0000     19.00
# crosses                          0.000     3.000    10.7500     72.00
# throw_ins                        0.000     1.000     5.0000    114.00
# corner_kicks                     0.000     0.000     1.0000     42.00
# corner_kicks_in                  0.000     0.000     0.0000     29.00
# corner_kicks_out                 0.000     0.000     0.0000     22.00
# corner_kicks_straight            0.000     0.000     0.0000      3.00
# passes_offsides                  0.000     0.000     1.0000      8.00
# passes_blocked                   0.000     2.000     5.0000     25.00
# sca                              2.000     6.000    13.7500     64.00
# sca_per90                        0.790     1.650     2.7375     14.69
# sca_passes_live                  2.000     5.000    10.0000     45.00
# sca_passes_dead                  0.000     0.000     1.0000     13.00
# sca_take_ons                     0.000     0.000     1.0000      8.00
# sca_shots                        0.000     0.000     1.0000      6.00
# sca_fouled                       0.000     0.000     0.0000      5.00
# sca_defense                      0.000     0.000     0.0000      3.00
# gca                              0.000     0.000     2.0000      7.00
# gca_per90                        0.000     0.000     0.3300      5.63
# gca_passes_live                  0.000     0.000     1.0000      6.00
# gca_passes_dead                  0.000     0.000     0.0000      2.00
# gca_take_ons                     0.000     0.000     0.0000      3.00
# gca_shots                        0.000     0.000     0.0000      2.00
# gca_fouled                       0.000     0.000     0.0000      2.00
# gca_defense                      0.000     0.000     0.0000      1.00
# tackles                          1.000     5.000    11.0000     44.00
# tackles_won                      1.000     3.000     7.0000     27.00
# tackles_def_3rd                  0.000     2.000     6.0000     22.00
# tackles_mid_3rd                  0.000     2.000     4.0000     21.00
# tackles_att_3rd                  0.000     0.000     2.0000      8.00
# challenge_tackles                0.000     2.000     5.7500     25.00
# challenges                       1.000     4.000    10.0000     34.00
# challenge_tackles_pct            0.000    50.000    66.7000    100.00
# challenges_lost                  0.000     2.000     5.0000     18.00
# blocks                           1.000     3.000     7.0000     23.00
# blocked_shots                    0.000     1.000     2.0000     15.00
# blocked_passes                   0.250     2.000     5.0000     18.00
# interceptions                    0.000     2.000     5.0000     25.00
# tackles_interceptions            2.000     8.000    17.0000     56.00
# clearances                       2.000     6.000    15.0000     92.00
# errors                           0.000     0.000     0.7500      4.00
# touches                         94.750   213.500   405.7500    910.00
# touches_def_pen_area             3.000    10.000    27.0000    367.00
# touches_def_3rd                 13.000    45.500   130.7500    445.00
# touches_mid_3rd                 28.250    81.500   181.2500    526.00
# touches_att_3rd                 13.250    42.000   101.0000    274.00
# touches_att_pen_area             2.000     7.000    14.0000     66.00
# touches_live_ball               94.750   213.500   405.7500    910.00
# take_ons                         1.000     4.000    11.0000     76.00
# take_ons_won                     0.000     2.000     4.0000     34.00
# take_ons_won_pct                 0.000    33.300    50.0000    100.00
# take_ons_tackled                 0.000     2.000     5.0000     37.00
# take_ons_tackled_pct             0.000    40.000    57.1000    100.00
# carries                         49.000   115.000   225.7500    566.00
# carries_distance               231.250   591.000  1144.2500   3728.00
# carries_progressive_distance   100.000   312.000   583.7500   2558.00
# carries_into_final_third         1.000     3.000     8.0000     34.00
# carries_into_penalty_area        0.000     0.000     2.0000     32.00
# miscontrols                      1.000     5.000    10.0000     37.00
# dispossessed                     0.000     2.000     6.0000     30.00
# passes_received                 59.250   132.500   256.0000    645.00
# cards_yellow_red                 0.000     0.000     0.0000      1.00
# fouls                            1.000     4.000     8.0000     26.00
# fouled                           1.000     3.000     7.0000     30.00
# offsides                         0.000     0.000     1.0000      8.00
# pens_won                         0.000     0.000     0.0000      1.00
# pens_conceded                    0.000     0.000     0.0000      2.00
# own_goals                        0.000     0.000     0.0000      2.00
# ball_recoveries                  6.000    14.000    27.0000     85.00
# aerials_won                      1.000     4.000     9.0000     47.00
# aerials_lost                     1.000     5.000    10.0000     41.00
# aerials_won_pct                 26.850    47.100    63.2250    100.00
# team_score                      40.914    40.914   179.5625    243.25

# %%
#drop cols
df = original_df.copy()
if 'ranker' in df.columns:
    df.drop(columns=['ranker'], inplace=True)
else: print(f'ranker doesnt exist in {file}')

#drop non per90 cols if it already have per90 cols
per90_cols = [c for c in df.columns if c.endswith('_per90')]
base = {c.replace('_per90', '') for c in per90_cols}
cols_to_drop = [c for c in df.columns if c in base]
df = df.drop(columns=cols_to_drop)

#Trim age
if df['age'].dtype == 'object':
    df['age'] = df['age'].str.split('-').str[0].str.strip()


# Encode positions
if 'position' in df.columns:
    df_encoded = (
        df
        .assign(
            position_fw=df['position'].str.contains('FW', na=False).astype(int),
            position_mf=df['position'].str.contains('MF', na=False).astype(int),
            position_df=df['position'].str.contains('DF', na=False).astype(int),
        )
        .drop(columns=['position'])
    )
else: print(f'position doesnt exist in {file}')


print('per90 cols :',sorted(per90_cols))

print('removed cols :',sorted(set(original_df.columns) - set(df_encoded.columns)))

print('len is equal' if len(per90_cols) == len(set(original_df.columns) - set(df_encoded.columns)) else 'len is not equal')

per90_cols = [c for c in df.columns if c.endswith('_per90')]
exclude_cols = [
    'ranker',
    'age',
    'birth_year',
    'minutes',
    'minutes_90s',
    'games',
    'games_starts',
    'position_fw',
    'position_mf',
    'position_df',
    'team',
    'team_score'
] + per90_cols


to_scale = [
    c for c in df.columns
    if c not in exclude_cols 
    and c not in ['minutes_90s']
    and df[c].dtype != 'object'
]

df_scaled = df_encoded.copy()
df_scaled[to_scale] = df_encoded[to_scale].div(df['minutes_90s'], axis=0)
df_scaled.replace([np.inf, -np.inf], 0, inplace=True)
df_scaled.rename(columns={c: f"{c}_per90" for c in to_scale}, inplace=True)
# Out:
#   Cell In[92], line 34
#     print('removed cols :'sorted(set(original_df.columns) - set(df_encoded.columns)))
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
per90_cols = [c for c in df.columns if c.endswith('_per90')]
exclude_cols = [
    'ranker',
    'age',
    'birth_year',
    'minutes',
    'minutes_90s',
    'games',
    'games_starts',
    'position_fw',
    'position_mf',
    'position_df',
    'team',
    'team_score'
] + per90_cols


to_scale = [
    c for c in df.columns
    if c not in exclude_cols 
    and c not in ['minutes_90s']
    and df[c].dtype != 'object'
]

df_scaled = df_encoded.copy()
df_scaled[to_scale] = df_encoded[to_scale].div(df['minutes_90s'], axis=0)
df_scaled.replace([np.inf, -np.inf], 0, inplace=True)
df_scaled.rename(columns={c: f"{c}_per90" for c in to_scale}, inplace=True)

# %%
df_scaled.describe().T
# Out:
#                                     count         mean         std  \
# birth_year                          450.0  1999.302222    4.114967
# games                               450.0     6.815556    2.987610
# games_starts                        450.0     4.888889    3.576228
# minutes                             450.0   439.013333  298.906649
# minutes_90s                         450.0     4.875556    3.320568
# pens_made_per90                     437.0     0.007291    0.045554
# through_balls_per90                    0.000000     0.000000     0.000000
# passes_switches_per90                  0.000000     0.000000     0.000000
# crosses_per90                          0.000000     0.000000     0.786517
# throw_ins_per90                        0.000000     0.000000     0.144958
# corner_kicks_per90                     0.000000     0.000000     0.000000
# corner_kicks_in_per90                  0.000000     0.000000     0.000000
# corner_kicks_out_per90                 0.000000     0.000000     0.000000
# corner_kicks_straight_per90            0.000000     0.000000     0.000000
# passes_offsides_per90                  0.000000     0.000000     0.000000
# passes_blocked_per90                   0.000000     0.125000     0.606061
# sca_per90                              0.000000     0.790000     1.650000
# sca_passes_live_per90                  0.000000     0.588235     1.250000
# sca_passes_dead_per90                  0.000000     0.000000     0.000000
# sca_take_ons_per90                     0.000000     0.000000     0.000000
# sca_shots_per90                        0.000000     0.000000     0.000000
# sca_fouled_per90                       0.000000     0.000000     0.000000
# sca_defense_per90                      0.000000     0.000000     0.000000
# gca_per90                              0.000000     0.000000     0.000000
# gca_passes_live_per90                  0.000000     0.000000     0.000000
# gca_passes_dead_per90                  0.000000     0.000000     0.000000
# gca_take_ons_per90                     0.000000     0.000000     0.000000
# gca_shots_per90                        0.000000     0.000000     0.000000
# gca_fouled_per90                       0.000000     0.000000     0.000000
# gca_defense_per90                      0.000000     0.000000     0.000000
# tackles_per90                          0.000000     0.647805     1.447529
# tackles_won_per90                      0.000000     0.304592     0.869565
# tackles_def_3rd_per90                  0.000000     0.100000     0.603030
# tackles_mid_3rd_per90                  0.000000     0.000000     0.500000
# tackles_att_3rd_per90                  0.000000     0.000000     0.000000
# challenge_tackles_per90                0.000000     0.025000     0.606061
# challenges_per90                       0.000000     0.597426     1.250000
# challenge_tackles_pct_per90            0.000000     0.397222     7.140179
# challenges_lost_per90                  0.000000     0.105263     0.517241
# blocks_per90                           0.000000     0.416667     0.898876
# blocked_shots_per90                    0.000000     0.000000     0.109890
# blocked_passes_per90                   0.000000     0.181818     0.555556
# interceptions_per90                    0.000000     0.000000     0.555556
# tackles_interceptions_per90            0.000000     1.000000     2.105263
# clearances_per90                       0.000000     0.708874     1.666667
# errors_per90                           0.000000     0.000000     0.000000
# touches_per90                          0.000000    40.869318    53.401168
# touches_def_pen_area_per90             0.000000     1.137802     2.500000
# touches_def_3rd_per90                  0.000000     5.858586    13.548387
# touches_mid_3rd_per90                  0.000000    13.601190    23.779762
# touches_att_3rd_per90                  0.000000     6.666667    13.571429
# touches_att_pen_area_per90             0.000000     0.707071     1.700000
# touches_live_ball_per90                0.000000    40.793561    53.401168
# take_ons_per90                         0.000000     0.305398     1.250000
# take_ons_won_per90                     0.000000     0.000000     0.416667
# take_ons_won_pct_per90                 0.000000     0.000000     5.319149
# take_ons_tackled_per90                 0.000000     0.000000     0.500000
# take_ons_tackled_pct_per90             0.000000     0.000000     6.079084
# carries_per90                          0.000000    21.926613    28.516484
# carries_distance_per90                 0.000000    99.000000   142.416667
# carries_progressive_distance_per90     0.000000    44.868421    71.428571
# carries_into_final_third_per90         0.000000     0.289855     0.909091
# carries_into_penalty_area_per90        0.000000     0.000000     0.100000
# miscontrols_per90                      0.000000     0.500000     1.250000
# dispossessed_per90                     0.000000     0.100000     0.681818
# passes_received_per90                  0.000000    24.504831    32.500000
# cards_yellow_red_per90                 0.000000     0.000000     0.000000
# fouls_per90                            0.000000     0.411036     0.923077
# fouled_per90                           0.000000     0.275901     0.829038
# offsides_per90                         0.000000     0.000000     0.000000
# pens_won_per90                         0.000000     0.000000     0.000000
# pens_conceded_per90                    0.000000     0.000000     0.000000
# own_goals_per90                        0.000000     0.000000     0.000000
# ball_recoveries_per90                  0.000000     2.400000     3.456005
# aerials_won_per90                      0.000000     0.416667     0.945946
# aerials_lost_per90                     0.000000     0.625000     1.250000
# aerials_won_pct_per90                  0.000000     4.793103     7.878378
# team_score                             0.000000    40.914000    40.914000
# position_fw                            0.000000     0.000000     0.000000
# position_mf                            0.000000     0.000000     0.000000
# position_df                            0.000000     0.000000     0.000000
#
#                                             75%          max
# birth_year                          2002.000000  2009.000000
# games                                 10.000000    10.000000
# games_starts                           8.000000    10.000000
# minutes                              703.250000   900.000000
# minutes_90s                            7.800000    10.000000
# pens_made_per90                        0.000000     0.500000
# pens_att_per90                         0.000000     0.500000
# cards_yellow_per90                     0.270270     2.500000
# cards_red_per90                        0.000000     0.227273
# progressive_carries_per90              2.400000    13.333333
# progressive_passes_per90               4.672448    13.125000
# progressive_passes_received_per90      5.476540    30.000000
# goals_per90                            0.140000     5.630000
# assists_per90                          0.110000     5.290000
# goals_assists_per90                    0.300000     5.630000
# goals_pens_per90                       0.120000     5.630000
# goals_assists_pens_per90               0.297500     5.630000
# xg_per90                               0.180000     1.400000
# xg_assist_per90                        0.120000     1.100000
# xg_xg_assist_per90                     0.307500     1.910000
# npxg_per90                             0.170000     1.400000
# npxg_xg_assist_per90                   0.300000     1.910000
# shots_on_target_pct_per90              6.756757  1000.000000
# shots_per90                            1.767500    11.250000
# shots_on_target_per90                  0.570000     8.180000
# goals_per_shot_per90                   0.012658     2.500000
# goals_per_shot_on_target_per90         0.034722     5.000000
# average_shot_distance_per90            5.217391   138.000000
# shots_free_kicks_per90                 0.000000     5.000000
# npxg_per_shot_per90                    0.024000     0.900000
# xg_net_per90                           0.000000     4.000000
# npxg_net_per90                         0.000000     4.000000
# passes_completed_per90                43.528646   220.000000
# passes_per90                          52.713636   220.000000
# passes_pct_per90                      36.886905  1000.000000
# passes_total_distance_per90          758.292105  2910.000000
# passes_progressive_distance_per90    260.328079   629.750000
# passes_completed_short_per90          20.909091   140.000000
# passes_short_per90                    23.000000   140.000000
# passes_pct_short_per90                40.608696  1000.000000
# passes_completed_medium_per90         19.627586    70.000000
# passes_medium_per90                   22.723315    70.000000
# passes_pct_medium_per90               36.569167  1000.000000
# passes_completed_long_per90            3.800000    10.666667
# passes_long_per90                      7.000000    34.500000
# passes_pct_long_per90                 17.021739   500.000000
# pass_xa_per90                          0.107143     0.800000
# xg_assist_net_per90                    0.000000     4.000000
# assisted_shots_per90                   1.208791     6.666667
# passes_into_final_third_per90          3.969035    25.000000
# passes_into_penalty_area_per90         1.052632     6.250000
# crosses_into_penalty_area_per90        0.273973     2.727273
# passes_live_per90                     48.396154   220.000000
# passes_dead_per90                      5.967391    20.000000
# passes_free_kicks_per90                1.410256     5.700000
# through_balls_per90                    0.227273     3.333333
# passes_switches_per90                  0.285714     1.900000
# crosses_per90                          2.608696    30.000000
# throw_ins_per90                        1.209091    20.000000
# corner_kicks_per90                     0.158730     6.470588
# corner_kicks_in_per90                  0.000000     5.000000
# corner_kicks_out_per90                 0.000000     3.188406
# corner_kicks_straight_per90            0.000000     0.428571
# passes_offsides_per90                  0.198077     5.000000
# passes_blocked_per90                   1.136364    10.000000
# sca_per90                              2.737500    14.690000
# sca_passes_live_per90                  2.000000    10.000000
# sca_passes_dead_per90                  0.113636     1.956522
# sca_take_ons_per90                     0.113636     4.000000
# sca_shots_per90                        0.200000    10.000000
# sca_fouled_per90                       0.100000     6.666667
# sca_defense_per90                      0.000000     2.500000
# gca_per90                              0.330000     5.630000
# gca_passes_live_per90                  0.224719     5.000000
# gca_passes_dead_per90                  0.000000     0.909091
# gca_take_ons_per90                     0.000000     0.555556
# gca_shots_per90                        0.000000     5.000000
# gca_fouled_per90                       0.000000     3.333333
# gca_defense_per90                      0.000000     0.185185
# tackles_per90                          2.219298    20.000000
# tackles_won_per90                      1.388889    10.000000
# tackles_def_3rd_per90                  1.111111    10.000000
# tackles_mid_3rd_per90                  0.900000    10.000000
# tackles_att_3rd_per90                  0.322581     5.000000
# challenge_tackles_per90                1.086957    20.000000
# challenges_per90                       2.000000    20.000000
# challenge_tackles_pct_per90           14.480519  1000.000000
# challenges_lost_per90                  1.000000     6.666667
# blocks_per90                           1.400000     5.000000
# blocked_shots_per90                    0.416667     5.000000
# blocked_passes_per90                   1.022727     5.000000
# interceptions_per90                    1.000000     5.000000
# tackles_interceptions_per90            3.230550    20.000000
# clearances_per90                       3.582409    20.000000
# errors_per90                           0.100000     1.666667
# touches_per90                         65.425000   230.000000
# touches_def_pen_area_per90             5.462766    40.250000
# touches_def_3rd_per90                 23.500000    80.000000
# touches_mid_3rd_per90                 31.636905   150.000000
# touches_att_3rd_per90                 20.000000   100.000000
# touches_att_pen_area_per90             3.593750    26.666667
# touches_live_ball_per90               65.425000   230.000000
# take_ons_per90                         2.660920    23.333333
# take_ons_won_per90                     1.000000    15.000000
# take_ons_won_pct_per90                11.902778  1000.000000
# take_ons_tackled_per90                 1.250000    16.666667
# take_ons_tackled_pct_per90            13.952991   500.000000
# carries_per90                         36.200000   130.000000
# carries_distance_per90               195.501792   800.000000
# carries_progressive_distance_per90   103.495614   260.000000
# carries_into_final_third_per90         1.616162    10.000000
# carries_into_penalty_area_per90        0.595238    10.000000
# miscontrols_per90                      2.380952    20.000000
# dispossessed_per90                     1.290323    10.000000
# passes_received_per90                 41.900273   230.000000
# cards_yellow_red_per90                 0.000000     0.188679
# fouls_per90                            1.553640    10.000000
# fouled_per90                           1.416925    10.000000
# offsides_per90                         0.166667     1.666667
# pens_won_per90                         0.000000     3.333333
# pens_conceded_per90                    0.000000     0.526316
# own_goals_per90                        0.000000     0.588235
# ball_recoveries_per90                  4.666667    20.000000
# aerials_won_per90                      2.187500    40.000000
# aerials_lost_per90                     2.087500    20.000000
# aerials_won_pct_per90                 15.071429   800.000000
# team_score                           179.562500   243.250000
# position_fw                            1.000000     1.000000
# position_mf                            1.000000     1.000000
# position_df                            1.000000     1.000000

# %%
modified_fbref_files = glob(f"{modified_path}/PL_outfield/*.csv", recursive=True)

for file in modified_fbref_files:
    subfolder,filename = file.split('/')[-2:]
    year = '20'+file.split('/')[-1][-6:-4]
    print(f"⚙️ Processing: {file}", f'\nyear is {year}')

    original_df = pd.read_csv(file)
        #drop cols

    df = original_df.copy()
    if 'ranker' in df.columns:
        df.drop(columns=['ranker'], inplace=True)
    else: print(f'ranker doesnt exist in {file}')

    #drop non per90 cols if it already have per90 cols
    per90_cols = [c for c in df.columns if c.endswith('_per90')]
    base = {c.replace('_per90', '') for c in per90_cols}
    cols_to_drop = [c for c in df.columns if c in base]
    df = df.drop(columns=cols_to_drop)

    #Trim age
    if df['age'].dtype == 'object':
        df['age'] = df['age'].str.split('-').str[0].str.strip()


    # Encode positions
    if 'position' in df.columns:
        df_encoded = (
            df
            .assign(
                position_fw=df['position'].str.contains('FW', na=False).astype(int),
                position_mf=df['position'].str.contains('MF', na=False).astype(int),
                position_df=df['position'].str.contains('DF', na=False).astype(int),
            )
            .drop(columns=['position'])
        )
    else: print(f'position doesnt exist in {file}')


    print('per90 cols :',sorted(per90_cols))

    print('removed cols :',sorted(set(original_df.columns) - set(df_encoded.columns)))

    print('len is equal' if len(per90_cols) == len(set(original_df.columns) - set(df_encoded.columns)) else 'len is not equal')

    per90_cols = [c for c in df.columns if c.endswith('_per90')]
    exclude_cols = [
        'ranker',
        'age',
        'birth_year',
        'minutes',
        'minutes_90s',
        'games',
        'games_starts',
        'position_fw',
        'position_mf',
        'position_df',
        'team',
        'team_score'
    ] + per90_cols


    to_scale = [
        c for c in df.columns
        if c not in exclude_cols 
        and c not in ['minutes_90s']
        and df[c].dtype != 'object'
    ]

    df_scaled = df_encoded.copy()
    df_scaled[to_scale] = df_encoded[to_scale].div(df['minutes_90s'], axis=0)
    df_scaled.replace([np.inf, -np.inf], 0, inplace=True)
    df_scaled.rename(columns={c: f"{c}_per90" for c in to_scale}, inplace=True)
    df_scaled.to_csv(file,index = True)
    print(f'saved modified version to {file}')
# Out:
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_21_22.csv
# year is 2022
# ranker doesnt exist in ../data/fbref/modified/PL_outfield/PL_outfield_21_22.csv
# position doesnt exist in ../data/fbref/modified/PL_outfield/PL_outfield_21_22.csv
# per90 cols : ['aerials_lost_per90', 'aerials_won_pct_per90', 'aerials_won_per90', 'assisted_shots_per90', 'assists_per90', 'average_shot_distance_per90', 'ball_recoveries_per90', 'blocked_passes_per90', 'blocked_shots_per90', 'blocks_per90', 'cards_red_per90', 'cards_yellow_per90', 'cards_yellow_red_per90', 'carries_distance_per90', 'carries_into_final_third_per90', 'carries_into_penalty_area_per90', 'carries_per90', 'carries_progressive_distance_per90', 'challenge_tackles_pct_per90', 'challenge_tackles_per90', 'challenges_lost_per90', 'challenges_per90', 'clearances_per90', 'corner_kicks_in_per90', 'corner_kicks_out_per90', 'corner_kicks_per90', 'corner_kicks_straight_per90', 'crosses_into_penalty_area_per90', 'crosses_per90', 'dispossessed_per90', 'errors_per90', 'fouled_per90', 'fouls_per90', 'gca_defense_per90', 'gca_fouled_per90', 'gca_passes_dead_per90', 'gca_passes_live_per90', 'gca_per90', 'gca_shots_per90', 'gca_take_ons_per90', 'goals_assists_pens_per90', 'goals_assists_per90', 'goals_pens_per90', 'goals_per90', 'goals_per_shot_on_target_per90', 'goals_per_shot_per90', 'interceptions_per90', 'miscontrols_per90', 'npxg_net_per90', 'npxg_per90', 'npxg_per_shot_per90', 'npxg_xg_assist_per90', 'offsides_per90', 'own_goals_per90', 'pass_xa_per90', 'passes_blocked_per90', 'passes_completed_long_per90', 'passes_completed_medium_per90', 'passes_completed_per90', 'passes_completed_short_per90', 'passes_dead_per90', 'passes_free_kicks_per90', 'passes_into_final_third_per90', 'passes_into_penalty_area_per90', 'passes_live_per90', 'passes_long_per90', 'passes_medium_per90', 'passes_offsides_per90', 'passes_pct_long_per90', 'passes_pct_medium_per90', 'passes_pct_per90', 'passes_pct_short_per90', 'passes_per90', 'passes_progressive_distance_per90', 'passes_received_per90', 'passes_short_per90', 'passes_switches_per90', 'passes_total_distance_per90', 'pens_att_per90', 'pens_conceded_per90', 'pens_made_per90', 'pens_won_per90', 'progressive_carries_per90', 'progressive_passes_per90', 'progressive_passes_received_per90', 'sca_defense_per90', 'sca_fouled_per90', 'sca_passes_dead_per90', 'sca_passes_live_per90', 'sca_per90', 'sca_shots_per90', 'sca_take_ons_per90', 'shots_free_kicks_per90', 'shots_on_target_pct_per90', 'shots_on_target_per90', 'shots_per90', 'tackles_att_3rd_per90', 'tackles_def_3rd_per90', 'tackles_interceptions_per90', 'tackles_mid_3rd_per90', 'tackles_per90', 'tackles_won_per90', 'take_ons_per90', 'take_ons_tackled_pct_per90', 'take_ons_tackled_per90', 'take_ons_won_pct_per90', 'take_ons_won_per90', 'through_balls_per90', 'throw_ins_per90', 'touches_att_3rd_per90', 'touches_att_pen_area_per90', 'touches_def_3rd_per90', 'touches_def_pen_area_per90', 'touches_live_ball_per90', 'touches_mid_3rd_per90', 'touches_per90', 'xg_assist_net_per90', 'xg_assist_per90', 'xg_net_per90', 'xg_per90', 'xg_xg_assist_per90']
# removed cols : ['Unnamed: 0', 'aerials_lost_per90', 'aerials_won_pct_per90', 'aerials_won_per90', 'assisted_shots_per90', 'average_shot_distance_per90', 'ball_recoveries_per90', 'blocked_passes_per90', 'blocked_shots_per90', 'blocks_per90', 'cards_red_per90', 'cards_yellow_per90', 'cards_yellow_red_per90', 'carries_distance_per90', 'carries_into_final_third_per90', 'carries_into_penalty_area_per90', 'carries_per90', 'carries_progressive_distance_per90', 'challenge_tackles_pct_per90', 'challenge_tackles_per90', 'challenges_lost_per90', 'challenges_per90', 'clearances_per90', 'corner_kicks_in_per90', 'corner_kicks_out_per90', 'corner_kicks_per90', 'corner_kicks_straight_per90', 'crosses_into_penalty_area_per90', 'crosses_per90', 'dispossessed_per90', 'errors_per90', 'fouled_per90', 'fouls_per90', 'gca_defense_per90', 'gca_fouled_per90', 'gca_passes_dead_per90', 'gca_passes_live_per90', 'gca_shots_per90', 'gca_take_ons_per90', 'goals_per_shot_on_target_per90', 'goals_per_shot_per90', 'interceptions_per90', 'miscontrols_per90', 'npxg_net_per90', 'npxg_per_shot_per90', 'offsides_per90', 'own_goals_per90', 'pass_xa_per90', 'passes_blocked_per90', 'passes_completed_long_per90', 'passes_completed_medium_per90', 'passes_completed_per90', 'passes_completed_short_per90', 'passes_dead_per90', 'passes_free_kicks_per90', 'passes_into_final_third_per90', 'passes_into_penalty_area_per90', 'passes_live_per90', 'passes_long_per90', 'passes_medium_per90', 'passes_offsides_per90', 'passes_pct_long_per90', 'passes_pct_medium_per90', 'passes_pct_per90', 'passes_pct_short_per90', 'passes_per90', 'passes_progressive_distance_per90', 'passes_received_per90', 'passes_short_per90', 'passes_switches_per90', 'passes_total_distance_per90', 'pens_att_per90', 'pens_conceded_per90', 'pens_made_per90', 'pens_won_per90', 'progressive_carries_per90', 'progressive_passes_per90', 'progressive_passes_received_per90', 'sca_defense_per90', 'sca_fouled_per90', 'sca_passes_dead_per90', 'sca_passes_live_per90', 'sca_shots_per90', 'sca_take_ons_per90', 'shots_free_kicks_per90', 'shots_on_target_pct_per90', 'tackles_att_3rd_per90', 'tackles_def_3rd_per90', 'tackles_interceptions_per90', 'tackles_mid_3rd_per90', 'tackles_per90', 'tackles_won_per90', 'take_ons_per90', 'take_ons_tackled_pct_per90', 'take_ons_tackled_per90', 'take_ons_won_pct_per90', 'take_ons_won_per90', 'through_balls_per90', 'throw_ins_per90', 'touches_att_3rd_per90', 'touches_att_pen_area_per90', 'touches_def_3rd_per90', 'touches_def_pen_area_per90', 'touches_live_ball_per90', 'touches_mid_3rd_per90', 'touches_per90', 'xg_assist_net_per90', 'xg_net_per90']
# len is not equal
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 72
#      64 to_scale = [
#      65     c for c in df.columns
#      66     if c not in exclude_cols
#      67     and c not in ['minutes_90s']
#      68     and df[c].dtype != 'object'
#      69 ]
#      71 df_scaled = df_encoded.copy()
# ---> 72 df_scaled[to_scale] = df_encoded[to_scale].div(df['minutes_90s'], axis=0)
#      73 df_scaled.replace([np.inf, -np.inf], 0, inplace=True)
#      74 df_scaled.rename(columns={c: f"{c}_per90" for c in to_scale}, inplace=True)
#
# File ~/champ/football-data-project/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~/champ/football-data-project/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~/champ/football-data-project/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Unnamed: 0'], dtype='object')] are in the [columns]"
