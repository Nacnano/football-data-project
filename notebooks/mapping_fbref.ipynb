# %%
# !pip install fuzzywuzzy
# !pip install python-Levenshtein
# Out:
# Requirement already satisfied: fuzzywuzzy in /home/kheaw/champ/football-data-project/.venv/lib/python3.13/site-packages (0.18.0)
# Requirement already satisfied: python-Levenshtein in /home/kheaw/champ/football-data-project/.venv/lib/python3.13/site-packages (0.27.3)
# Requirement already satisfied: Levenshtein==0.27.3 in /home/kheaw/champ/football-data-project/.venv/lib/python3.13/site-packages (from python-Levenshtein) (0.27.3)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /home/kheaw/champ/football-data-project/.venv/lib/python3.13/site-packages (from Levenshtein==0.27.3->python-Levenshtein) (3.14.3)

# %% [markdown]
# # Map UEFA score
#
# map score to each fbref data by chooing best either team score or country part

# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import process
from glob import glob
import os

# --- Display setup ---
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# --- Paths ---
data_path = "../data/fbref/"
modified_path = "../data/fbref/modified"
uefa_data_path = "../data/uefa/"
os.makedirs(modified_path, exist_ok=True)

# --- Preload ranking data once ---
def load_uefa_ranking(year):
    rankingdf = pd.read_csv(os.path.join(uefa_data_path, f'UEFA_Ranking_{year}.csv'))
    rankingdf['used_point'] = np.where(
        rankingdf['Total Points'] >= rankingdf['Country Part'],
        rankingdf['Total Points'],
        rankingdf['Country Part']
    )

    choices = rankingdf['team'].unique()
    return rankingdf,choices

# --- Matching function ---
def match_team(name,rankingdf,choices):
    if pd.isna(name): 
        return np.nan
    match, score = process.extractOne(name, choices)
    if score > 70:
        return rankingdf.loc[rankingdf['team'] == match, 'used_point'].iloc[0]
    return 0

# --- Outfield Players ---
fbref_files = glob(f"{data_path}/**/*.csv", recursive=True)

for file in fbref_files:
    subfolder,filename = file.split('/')[-2:]
    year = '20'+file.split('/')[-1][-6:-4]
    print(f"⚙️ Processing: {file}", f'\nyear is {year}')
    rankingdf,choices = load_uefa_ranking(year)

    df = pd.read_csv(os.path.join(file))
    
    # Map UEFA coefficient
    df['team_score'] = df['team'].apply(lambda x: match_team(x, rankingdf, choices))
    #df_encoded.drop(columns=['team'], inplace=True)

    # Save cleaned file
    os.makedirs(os.path.join(modified_path,subfolder), exist_ok=True)
    output_file = os.path.join(modified_path, subfolder, filename)
    df.to_csv(output_file, index=False)
    print(f"Saved to: {output_file}")
# Out:
# ⚙️ Processing: ../data/fbref/PL_team/PL_team_22_23.csv
# year is 2023
# Saved to: ../data/fbref/modified/PL_team/PL_team_22_23.csv
# ⚙️ Processing: ../data/fbref/PL_team/PL_team_24_25.csv
# year is 2025
# Saved to: ../data/fbref/modified/PL_team/PL_team_24_25.csv
# ⚙️ Processing: ../data/fbref/PL_team/PL_team_20_21.csv
# year is 2021
# Saved to: ../data/fbref/modified/PL_team/PL_team_20_21.csv
# ⚙️ Processing: ../data/fbref/PL_team/PL_team_21_22.csv
# year is 2022
# Saved to: ../data/fbref/modified/PL_team/PL_team_21_22.csv
# ⚙️ Processing: ../data/fbref/PL_team/PL_team_23_24.csv
# year is 2024
# Saved to: ../data/fbref/modified/PL_team/PL_team_23_24.csv
# ⚙️ Processing: ../data/fbref/PL_team/PL_team_25_26.csv
# year is 2026
# Saved to: ../data/fbref/modified/PL_team/PL_team_25_26.csv
# ⚙️ Processing: ../data/fbref/modified/PL_team/PL_team_22_23.csv
# year is 2023
# Saved to: ../data/fbref/modified/PL_team/PL_team_22_23.csv
# ⚙️ Processing: ../data/fbref/modified/PL_team/PL_team_24_25.csv
# year is 2025
# Saved to: ../data/fbref/modified/PL_team/PL_team_24_25.csv
# ⚙️ Processing: ../data/fbref/modified/PL_team/PL_team_20_21.csv
# year is 2021
# Saved to: ../data/fbref/modified/PL_team/PL_team_20_21.csv
# ⚙️ Processing: ../data/fbref/modified/PL_team/PL_team_21_22.csv
# year is 2022
# Saved to: ../data/fbref/modified/PL_team/PL_team_21_22.csv
# ⚙️ Processing: ../data/fbref/modified/PL_team/PL_team_23_24.csv
# year is 2024
# Saved to: ../data/fbref/modified/PL_team/PL_team_23_24.csv
# ⚙️ Processing: ../data/fbref/modified/PL_team/PL_team_25_26.csv
# year is 2026
# Saved to: ../data/fbref/modified/PL_team/PL_team_25_26.csv
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_21_22.csv
# year is 2022
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_21_22.csv
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_20_21.csv
# year is 2021
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_20_21.csv
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_22_23.csv
# year is 2023
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_22_23.csv
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_25_26.csv
# year is 2026
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_25_26.csv
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_24_25.csv
# year is 2025
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_24_25.csv
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_23_24.csv
# year is 2024
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_23_24.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_21_22.csv
# year is 2022
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_21_22.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_23_24.csv
# year is 2024
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_23_24.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_22_23.csv
# year is 2023
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_22_23.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_24_25.csv
# year is 2025
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_24_25.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_20_21.csv
# year is 2021
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_20_21.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_25_26.csv
# year is 2026
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_25_26.csv
# ⚙️ Processing: ../data/fbref/PL_keeper/PL_keeper_21_22.csv
# year is 2022
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_21_22.csv
# ⚙️ Processing: ../data/fbref/PL_keeper/PL_keeper_20_21.csv
# year is 2021
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_20_21.csv
# ⚙️ Processing: ../data/fbref/PL_keeper/PL_keeper_22_23.csv
# year is 2023
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_22_23.csv
# ⚙️ Processing: ../data/fbref/PL_keeper/PL_keeper_25_26.csv
# year is 2026
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_25_26.csv
# ⚙️ Processing: ../data/fbref/PL_keeper/PL_keeper_24_25.csv
# year is 2025
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_24_25.csv
# ⚙️ Processing: ../data/fbref/PL_keeper/PL_keeper_23_24.csv
# year is 2024
# Saved to: ../data/fbref/modified/PL_keeper/PL_keeper_23_24.csv
# ⚙️ Processing: ../data/fbref/PL_outfield/PL_outfield_21_22.csv
# year is 2022
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_21_22.csv
# ⚙️ Processing: ../data/fbref/PL_outfield/PL_outfield_23_24.csv
# year is 2024
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_23_24.csv
# ⚙️ Processing: ../data/fbref/PL_outfield/PL_outfield_22_23.csv
# year is 2023
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_22_23.csv
# ⚙️ Processing: ../data/fbref/PL_outfield/PL_outfield_24_25.csv
# year is 2025
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_24_25.csv
# ⚙️ Processing: ../data/fbref/PL_outfield/PL_outfield_20_21.csv
# year is 2021
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_20_21.csv
# ⚙️ Processing: ../data/fbref/PL_outfield/PL_outfield_25_26.csv
# year is 2026
# Saved to: ../data/fbref/modified/PL_outfield/PL_outfield_25_26.csv

# %% [markdown]
# # Feature engineering : outfield
#
# trim age, encode position and make stats to per90

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
modified_fbref_files = glob(f"{modified_path}/PL_outfield/*.csv", recursive=True)

for file in modified_fbref_files:
    subfolder,filename = file.split('/')[-2:]
    year = '20'+file.split('/')[-1][-6:-4]
    print(f"⚙️ Processing: {file}", f'\nyear is {year}')

    original_df = pd.read_csv(file)
        #drop cols

    df = original_df.copy()
    if 'ranker' in df.columns:
        df.drop(columns=['ranker'], inplace=True)
    else: print(f'ranker doesnt exist in {file}')

    #drop non per90 cols if it already have per90 cols
    per90_cols = [c for c in df.columns if c.endswith('_per90')]
    base = {c.replace('_per90', '') for c in per90_cols}
    cols_to_drop = [c for c in df.columns if c in base]
    df = df.drop(columns=cols_to_drop)

    #Trim age
    if df['age'].dtype == 'object':
        df['age'] = df['age'].str.split('-').str[0].str.strip()


    # Encode positions
    if 'position' in df.columns:
        df_encoded = (
            df
            .assign(
                position_fw=df['position'].str.contains('FW', na=False).astype(int),
                position_mf=df['position'].str.contains('MF', na=False).astype(int),
                position_df=df['position'].str.contains('DF', na=False).astype(int),
            )
            .drop(columns=['position'])
        )
    else: print(f'position doesnt exist in {file}')


    print('per90 cols :',sorted(per90_cols))

    print('removed cols :',sorted(set(original_df.columns) - set(df_encoded.columns)))

    print('len is equal' if len(per90_cols) == len(set(original_df.columns) - set(df_encoded.columns)) else 'len is not equal')

    per90_cols = [c for c in df.columns if c.endswith('_per90')]
    exclude_cols = [
        'ranker',
        'age',
        'birth_year',
        'minutes',
        'minutes_90s',
        'games',
        'games_starts',
        'position_fw',
        'position_mf',
        'position_df',
        'team',
        'team_score'
    ] + per90_cols


    to_scale = [
        c for c in df.columns
        if c not in exclude_cols 
        and c not in ['minutes_90s']
        and df[c].dtype != 'object'
    ]

    df_scaled = df_encoded.copy()
    df_scaled[to_scale] = df_encoded[to_scale].div(df['minutes_90s'], axis=0)
    df_scaled.replace([np.inf, -np.inf], 0, inplace=True)
    df_scaled.rename(columns={c: f"{c}_per90" for c in to_scale}, inplace=True)
    df_scaled.to_csv(file,index = True)
    print(f'saved modified version to {file}')
# Out:
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_21_22.csv
# year is 2022
# per90 cols : ['assists_per90', 'gca_per90', 'goals_assists_pens_per90', 'goals_assists_per90', 'goals_pens_per90', 'goals_per90', 'npxg_per90', 'npxg_xg_assist_per90', 'sca_per90', 'shots_on_target_per90', 'shots_per90', 'xg_assist_per90', 'xg_per90', 'xg_xg_assist_per90']
# removed cols : ['assists', 'gca', 'goals', 'goals_assists', 'goals_pens', 'npxg', 'npxg_xg_assist', 'position', 'ranker', 'sca', 'shots', 'shots_on_target', 'xg', 'xg_assist']
# len is equal
# saved modified version to ../data/fbref/modified/PL_outfield/PL_outfield_21_22.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_23_24.csv
# year is 2024
# per90 cols : ['assists_per90', 'gca_per90', 'goals_assists_pens_per90', 'goals_assists_per90', 'goals_pens_per90', 'goals_per90', 'npxg_per90', 'npxg_xg_assist_per90', 'sca_per90', 'shots_on_target_per90', 'shots_per90', 'xg_assist_per90', 'xg_per90', 'xg_xg_assist_per90']
# removed cols : ['assists', 'gca', 'goals', 'goals_assists', 'goals_pens', 'npxg', 'npxg_xg_assist', 'position', 'ranker', 'sca', 'shots', 'shots_on_target', 'xg', 'xg_assist']
# len is equal
# saved modified version to ../data/fbref/modified/PL_outfield/PL_outfield_23_24.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_22_23.csv
# year is 2023
# per90 cols : ['assists_per90', 'gca_per90', 'goals_assists_pens_per90', 'goals_assists_per90', 'goals_pens_per90', 'goals_per90', 'npxg_per90', 'npxg_xg_assist_per90', 'sca_per90', 'shots_on_target_per90', 'shots_per90', 'xg_assist_per90', 'xg_per90', 'xg_xg_assist_per90']
# removed cols : ['assists', 'gca', 'goals', 'goals_assists', 'goals_pens', 'npxg', 'npxg_xg_assist', 'position', 'ranker', 'sca', 'shots', 'shots_on_target', 'xg', 'xg_assist']
# len is equal
# saved modified version to ../data/fbref/modified/PL_outfield/PL_outfield_22_23.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_24_25.csv
# year is 2025
# per90 cols : ['assists_per90', 'gca_per90', 'goals_assists_pens_per90', 'goals_assists_per90', 'goals_pens_per90', 'goals_per90', 'npxg_per90', 'npxg_xg_assist_per90', 'sca_per90', 'shots_on_target_per90', 'shots_per90', 'xg_assist_per90', 'xg_per90', 'xg_xg_assist_per90']
# removed cols : ['assists', 'gca', 'goals', 'goals_assists', 'goals_pens', 'npxg', 'npxg_xg_assist', 'position', 'ranker', 'sca', 'shots', 'shots_on_target', 'xg', 'xg_assist']
# len is equal
# saved modified version to ../data/fbref/modified/PL_outfield/PL_outfield_24_25.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_20_21.csv
# year is 2021
# per90 cols : ['assists_per90', 'gca_per90', 'goals_assists_pens_per90', 'goals_assists_per90', 'goals_pens_per90', 'goals_per90', 'npxg_per90', 'npxg_xg_assist_per90', 'sca_per90', 'shots_on_target_per90', 'shots_per90', 'xg_assist_per90', 'xg_per90', 'xg_xg_assist_per90']
# removed cols : ['assists', 'gca', 'goals', 'goals_assists', 'goals_pens', 'npxg', 'npxg_xg_assist', 'position', 'ranker', 'sca', 'shots', 'shots_on_target', 'xg', 'xg_assist']
# len is equal
# saved modified version to ../data/fbref/modified/PL_outfield/PL_outfield_20_21.csv
# ⚙️ Processing: ../data/fbref/modified/PL_outfield/PL_outfield_25_26.csv
# year is 2026
# per90 cols : ['assists_per90', 'gca_per90', 'goals_assists_pens_per90', 'goals_assists_per90', 'goals_pens_per90', 'goals_per90', 'npxg_per90', 'npxg_xg_assist_per90', 'sca_per90', 'shots_on_target_per90', 'shots_per90', 'xg_assist_per90', 'xg_per90', 'xg_xg_assist_per90']
# removed cols : ['assists', 'gca', 'goals', 'goals_assists', 'goals_pens', 'npxg', 'npxg_xg_assist', 'position', 'ranker', 'sca', 'shots', 'shots_on_target', 'xg', 'xg_assist']
# len is equal
# saved modified version to ../data/fbref/modified/PL_outfield/PL_outfield_25_26.csv

# %% [markdown]
# # Feature engineering : outfield
#
# trim age and make stats to per90

# %%
modified_fbref_files = glob(f"{modified_path}/PL_keeper/*.csv", recursive=True)

for file in modified_fbref_files:
    subfolder,filename = file.split('/')[-2:]
    year = '20'+file.split('/')[-1][-6:-4]
    print(f"⚙️ Processing: {file}", f'\nyear is {year}')

    original_df_keeper = pd.read_csv(file)
    df_keeper = original_df_keeper.copy()

    # drop cols
    if 'matches' in df_keeper.columns:
        df_keeper.drop(columns=['matches'], inplace=True)

    if 'ranker' in df_keeper.columns:
        df_keeper.drop(columns=['ranker'], inplace=True)

    # drop base cols if per90 exists
    per90_cols = [c for c in df_keeper.columns if c.endswith('_per90')]
    base = {c.replace('_per90', '') for c in per90_cols}
    df_keeper.drop(columns=[c for c in df_keeper.columns if c in base], inplace=True)

    # age cleanup
    if df_keeper['age'].dtype == 'object':
        df_keeper['age'] = df_keeper['age'].str.split('-').str[0].astype(int)

    # exclude list
    exclude_cols = [
        'player','nationality','position','team','age','birth_year',
        'gk_games','gk_games_starts','gk_minutes','team_score',
        'minutes_90s'
    ] + per90_cols

    to_scale = [
        c for c in df_keeper.columns
        if c not in exclude_cols
        and df_keeper[c].dtype != 'object'
    ]

    # scale
    df_keeper_scaled = df_keeper.copy()
    df_keeper_scaled[to_scale] = df_keeper_scaled[to_scale].div(
        df_keeper_scaled['minutes_90s'].replace(0, np.nan), axis=0
    )

    df_keeper_scaled.rename(
        columns={c: f"{c}_per90" for c in to_scale},
        inplace=True
    )

    df_keeper_scaled.replace([np.inf, -np.inf], 0, inplace=True)

    df_keeper_scaled.to_csv(file, index=True)
# Out:
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_21_22.csv
# year is 2022
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_20_21.csv
# year is 2021
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_22_23.csv
# year is 2023
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_25_26.csv
# year is 2026
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_24_25.csv
# year is 2025
# ⚙️ Processing: ../data/fbref/modified/PL_keeper/PL_keeper_23_24.csv
# year is 2024

# %%
df_keeper_scaled.describe().T
# Out:
#                                             count         mean        std  \
# age                                          40.0    28.625000   3.705073
# birth_year                                   40.0  1994.025000   3.519087
# gk_games                                     40.0    19.400000  13.028175
# gk_games_starts                              40.0    19.000000  13.347428
# minutes_90s                                  40.0    19.000000  13.060255
# gk_goals_against_per90                       40.0     2.245250   3.370139
# gk_shots_on_target_against_per90             39.0     5.035057   1.569566
# gk_saves_per90                               39.0     3.373695   1.455863
# gk_save_pct_per90                            39.0    20.156673  79.522292
# gk_wins_per90                                39.0     0.362642   0.222590
# gk_ties_per90                                39.0     0.180144   0.112849
# gk_losses_per90                              39.0     0.407036   0.233730
# gk_clean_sheets_per90                        39.0     0.184514   0.137141
# gk_clean_sheets_pct_per90                    39.0     1.599230   2.636214
# gk_pens_att_per90                            39.0     0.122342   0.096004
# gk_pens_allowed_per90                        39.0     0.102981   0.092921
# gk_pens_saved_per90                          39.0     0.014347   0.040961
# gk_pens_missed_per90                         39.0     0.005014   0.020355
# gk_pens_save_pct_per90                       39.0     0.839420   3.623084
# gk_free_kick_goals_against_per90             39.0     0.015498   0.039212
# gk_corner_kick_goals_against_per90           39.0     0.252349   0.274863
# gk_own_goals_against_per90                   39.0     0.078409   0.162407
# gk_psxg_per90                                39.0     1.481498   0.482152
# gk_psnpxg_per_shot_on_target_against_per90   39.0     0.042097   0.067418
# gk_psxg_net_per90                            40.0    -0.633750   3.045924
# gk_passes_completed_launched_per90           39.0     4.817075   2.566326
# gk_passes_launched_per90                     39.0    13.937839   5.783762
# gk_passes_pct_launched_per90                 39.0    10.266163  39.754495
# gk_passes_per90                              39.0    30.806893   7.861727
# gk_passes_throws_per90                       39.0     4.471532   1.019826
# gk_pct_passes_launched_per90                 39.0    15.233633  66.508833
# gk_passes_length_avg_per90                   39.0    10.647246  40.576070
# gk_goal_kicks_per90                          39.0     6.406615   2.526521
# gk_pct_goal_kicks_launched_per90             39.0    10.722373  27.558795
# gk_goal_kick_length_avg_per90                39.0     9.787217  30.079969
# gk_crosses_per90                             39.0    13.457558   3.662052
# gk_crosses_stopped_per90                     39.0     0.911911   0.423351
# gk_crosses_stopped_pct_per90                 39.0     0.979912   1.845088
# gk_def_actions_outside_pen_area_per90        40.0     1.338750   1.060994
# gk_avg_distance_def_actions_per90            39.0     4.166551  15.267973
# team_score                                   40.0    63.360050  80.571626
#
#                                                     min          25%  \
# age                                           20.000000    26.000000
# birth_year                                  1985.000000  1992.000000
# gk_games                                       1.000000     8.250000
# gk_games_starts                                0.000000     5.750000
# minutes_90s                                    0.000000     6.825000
# gk_goals_against_per90                         0.000000     1.330000
# gk_shots_on_target_against_per90               2.156250     4.021055
# gk_saves_per90                                 1.406250     2.808451
# gk_save_pct_per90                              1.674603     2.178083
# gk_wins_per90                                  0.000000     0.227390
# gk_ties_per90                                  0.000000     0.129614
# gk_losses_per90                                0.000000     0.277085
# gk_clean_sheets_per90                          0.000000     0.066964
# gk_clean_sheets_pct_per90                      0.000000     0.295925
# gk_pens_att_per90                              0.000000     0.032783
# gk_pens_allowed_per90                          0.000000     0.000000
# gk_pens_saved_per90                            0.000000     0.000000
# gk_pens_missed_per90                           0.000000     0.000000
# gk_pens_save_pct_per90                         0.000000     0.000000
# gk_free_kick_goals_against_per90               0.000000     0.000000
# gk_corner_kick_goals_against_per90             0.000000     0.117114
# gk_own_goals_against_per90                     0.000000     0.000000
# gk_psxg_per90                                  0.500000     1.169762
# gk_psnpxg_per_shot_on_target_against_per90     0.006842     0.009487
# gk_psxg_net_per90                            -19.200000    -0.300000
# gk_passes_completed_launched_per90             1.394737     3.027465
# gk_passes_launched_per90                       5.921053     9.630361
# gk_passes_pct_launched_per90                   0.608309     1.108376
# gk_passes_per90                               17.687500    25.301274
# gk_passes_throws_per90                         2.093023     3.636626
# gk_pct_passes_launched_per90                   0.376316     1.001370
# gk_passes_length_avg_per90                     0.631579     1.069855
# gk_goal_kicks_per90                            2.676056     4.504713
# gk_pct_goal_kicks_launched_per90               0.392105     1.678460
# gk_goal_kick_length_avg_per90                  0.584211     1.267574
# gk_crosses_per90                               7.666667    10.479911
# gk_crosses_stopped_per90                       0.000000     0.645763
# gk_crosses_stopped_pct_per90                   0.000000     0.195104
# gk_def_actions_outside_pen_area_per90          0.000000     0.737500
# gk_avg_distance_def_actions_per90              0.296667     0.529051
# team_score                                     0.000000     0.000000
#
#                                                     50%          75%  \
# age                                           29.500000    30.250000
# birth_year                                  1993.000000  1996.250000
# gk_games                                      17.500000    32.000000
# gk_games_starts                               17.500000    32.000000
# minutes_90s                                   17.500000    31.175000
# gk_goals_against_per90                         1.645000     2.052500
# gk_shots_on_target_against_per90               4.821918     5.864457
# gk_saves_per90                                 3.166667     3.911946
# gk_save_pct_per90                              3.452381     9.125000
# gk_wins_per90                                  0.342105     0.513158
# gk_ties_per90                                  0.200000     0.248288
# gk_losses_per90                                0.421053     0.500000
# gk_clean_sheets_per90                          0.191781     0.250982
# gk_clean_sheets_pct_per90                      0.694118     1.366667
# gk_pens_att_per90                              0.116279     0.200000
# gk_pens_allowed_per90                          0.100000     0.177521
# gk_pens_saved_per90                            0.000000     0.000000
# gk_pens_missed_per90                           0.000000     0.000000
# gk_pens_save_pct_per90                         0.000000     0.000000
# gk_free_kick_goals_against_per90               0.000000     0.013158
# gk_corner_kick_goals_against_per90             0.200000     0.296313
# gk_own_goals_against_per90                     0.032362     0.102632
# gk_psxg_per90                                  1.510448     1.730833
# gk_psnpxg_per_shot_on_target_against_per90     0.015294     0.042292
# gk_psxg_net_per90                             -0.085000     0.052500
# gk_passes_completed_launched_per90             3.921053     6.050000
# gk_passes_launched_per90                      12.581602    17.875000
# gk_passes_pct_launched_per90                   1.842857     4.835417
# gk_passes_per90                               29.656085    36.175609
# gk_passes_throws_per90                         4.686567     5.139474
# gk_pct_passes_launched_per90                   1.492105     4.817778
# gk_passes_length_avg_per90                     1.767296     4.832849
# gk_goal_kicks_per90                            6.500000     7.660739
# gk_pct_goal_kicks_launched_per90               2.796429     7.952083
# gk_goal_kick_length_avg_per90                  2.119497     6.268750
# gk_crosses_per90                              13.666667    15.244807
# gk_crosses_stopped_per90                       0.904977     1.202740
# gk_crosses_stopped_pct_per90                   0.326861     0.661395
# gk_def_actions_outside_pen_area_per90          1.120000     1.647500
# gk_avg_distance_def_actions_per90              0.752381     1.793333
# team_score                                    37.953000    86.625000
#
#                                                     max
# age                                           38.000000
# birth_year                                  2002.000000
# gk_games                                      38.000000
# gk_games_starts                               38.000000
# minutes_90s                                   38.000000
# gk_goals_against_per90                        22.500000
# gk_shots_on_target_against_per90              10.000000
# gk_saves_per90                                10.000000
# gk_save_pct_per90                            500.000000
# gk_wins_per90                                  0.833333
# gk_ties_per90                                  0.400000
# gk_losses_per90                                1.000000
# gk_clean_sheets_per90                          0.500000
# gk_clean_sheets_pct_per90                     12.500000
# gk_pens_att_per90                              0.375000
# gk_pens_allowed_per90                          0.375000
# gk_pens_saved_per90                            0.222222
# gk_pens_missed_per90                           0.116279
# gk_pens_save_pct_per90                        22.222222
# gk_free_kick_goals_against_per90               0.222222
# gk_corner_kick_goals_against_per90             1.500000
# gk_own_goals_against_per90                     1.000000
# gk_psxg_per90                                  2.475000
# gk_psnpxg_per_shot_on_target_against_per90     0.300000
# gk_psxg_net_per90                              0.750000
# gk_passes_completed_launched_per90            15.000000
# gk_passes_launched_per90                      30.000000
# gk_passes_pct_launched_per90                 250.000000
# gk_passes_per90                               54.700000
# gk_passes_throws_per90                         6.470588
# gk_pct_passes_launched_per90                 416.500000
# gk_passes_length_avg_per90                   254.000000
# gk_goal_kicks_per90                           15.000000
# gk_pct_goal_kicks_launched_per90             166.500000
# gk_goal_kick_length_avg_per90                186.500000
# gk_crosses_per90                              24.666667
# gk_crosses_stopped_per90                       2.000000
# gk_crosses_stopped_pct_per90                  10.000000
# gk_def_actions_outside_pen_area_per90          6.000000
# gk_avg_distance_def_actions_per90             95.000000
# team_score                                   254.000000
